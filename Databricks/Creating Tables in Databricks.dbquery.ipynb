-- %%
-- Gold Tables
-- Creating Entity Scores Table
CREATE OR REPLACE TABLE `projecto-clinical-data-quality-engine`.gold.entity_scores
AS SELECT * FROM read_files('/Volumes/projecto-clinical-data-quality-engine/gold/uploaded/entity_scores.parquet');

-- Creating Dataset Score Table
CREATE OR REPLACE TABLE `projecto-clinical-data-quality-engine`.gold.dataset_score
AS SELECT * FROM read_files('/Volumes/projecto-clinical-data-quality-engine/gold/uploaded/dataset_score.parquet');

-- Creating Severity Distribution Table
CREATE OR REPLACE TABLE `projecto-clinical-data-quality-engine`.gold.severity_distribution
AS SELECT * FROM read_files('/Volumes/projecto-clinical-data-quality-engine/gold/uploaded/severity_distribution.parquet');

-- Creating Score by Entity Type Table
CREATE OR REPLACE TABLE `projecto-clinical-data-quality-engine`.gold.score_by_entity_type
AS SELECT * FROM read_files('/Volumes/projecto-clinical-data-quality-engine/gold/uploaded/score_by_entity_type.parquet');

-- Creating Entity Type Contribution Table
CREATE OR REPLACE TABLE `projecto-clinical-data-quality-engine`.gold.entity_type_contribution
AS SELECT * FROM read_files('/Volumes/projecto-clinical-data-quality-engine/gold/uploaded/entity_type_contribution.parquet');
